# %%
import math
usd = float(input("nhap so tien usd can doi: "))
tygia = float(input("nhap ty gia vnd/usd: "))
vnd = usd * tygia
print("so tien vnd la: ", float(vnd))
# Out:
# nhap so tien usd can doi: 2
# nhap ty gia vnd/usd: 32.32326
# so tien vnd la:  64.64652
